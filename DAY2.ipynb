# %%
import numpy as np
import matplotlib.pyplot as plt
height = np.random.normal(140, 20, 1000)
plt.figure(dpi=200)
plt.title("Height Distribuion")
plt.xlabel("Height (cm) ")
plt.ylabel("Frequency")
plt.hist(height, bins=30, ec="gold")
plt.show()

# %% [markdown]
# The code is creating a histogram of 1000 random values that follow a normal distribution with a mean of 140 and a standard deviation of 20. The histogram has 30 bins and each bin has a gold edge. The histogram is displayed with a title, labels for the x-axis and y-axis, and a high-resolution figure.

# %% [markdown]
# Q3)JUPYTER:
# Jupyter is a project that develops open-source software, standards, and services for interactive computing across different programming languages. Some of the applications that Jupyter offers are JupyterLab, Jupyter Notebook, and Voilà. JupyterLab is the next-generation web-based interface for notebooks, code, and data. Jupyter Notebook is the classic web-based interface for creating and sharing computational documents.
#
# NOTEPAD:
# Notepad is a text editor that is included in Windows and that you can use for editing code or plain text.Notepad is different from Jupyter, which is a web-based platform for interactive computing and data visualization.

# %% [markdown]
# Q4)COMPILER:
# The Compiler is a translator which takes input i.e., High-Level Language, and produces an output of low-level language i.e. machine or assembly language. The work of a Compiler is to transform the codes written in the programming language into machine code (format of 0s and 1s) so that computers can understand.
# Compiled code runs faster in comparison to Interpreted code.
# Compilers help in improving the security of Applications.
# As Compilers give Debugging tools, which help in fixing errors easily.
#
#
# INTERPRETER:
# An Interpreter is a program that translates a programming language into a comprehensible language. The interpreter converts high-level language to an intermediate language. It contains pre-compiled code, source code, etc.
# Programs written in an Interpreted language are easier to debug.
# Interpreters allow the management of memory automatically, which reduces memory error risks.
# Interpreted Language is more flexible than a Compiled language.

# %% [markdown]
# Q5)
# Data structures are an integral part of computers used for the arrangement of data in memory. They are essential and responsible for organizing, processing, accessing, and storing data efficiently.
#
# Data structures have gained its importance for the following reasons:
#
# 1. In software design, Data structures are known to be major factors for collection, storing and organizing of data rather than algorithms in some programming languages.
#
# 2. Often Data structures are used in the combination of algorithms. This allows the management of large amounts of data in an efficient way.

# %%
name = input("Enter your name: ")
print(f"Hello mr. {name}, Welcome to Python Programming")
# Out:
# Enter your name: MANISHA KUMARI
# Hello mr. MANISHA KUMARI, Welcome to Python Programming

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
x = 100
